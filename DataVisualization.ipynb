# %% [markdown]
# <a href="https://colab.research.google.com/github/quantumhome/DataAnalysisCaseStudy/blob/master/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/sample_data/mtcars.csv')
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp     hp  drat     wt   qsec  \
# 0      1            Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46
# 1      2        Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02
# 2      3           Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61
# 3      4       Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44
# 4      5    Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02
# 5      6              Valiant  18.1  6.0  225.0  105.0  2.76  3.460    NaN
# 6      7           Duster 360  14.3  8.0  360.0  245.0  3.21  3.570  15.84
# 7      8            Merc 240D  24.4  4.0  146.7   62.0  3.69  3.190  20.00
# 8      9             Merc 230  22.8  4.0  140.8    NaN  3.92  3.150  22.90
# 9     10             Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30
# 10    11            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  18.90
# ...

# %%
# barplot using column cyl  and hp
# sns.barplot(x=df['cyl'], y = df['hp'], palette='Set1')
# sns.barplot(x=df['cyl'], y = df['hp'], palette='Set2')
# sns.barplot(x=df['cyl'], y = df['hp'], palette='Set3')
# sns.barplot(x=df['cyl'], y = df['hp'], palette='Paired')
# sns.barplot(x=df['cyl'], y = df['hp'], palette='rocket')
# sns.barplot(x=df['cyl'], y = df['hp'], palette='flare')
plt.xlabel('Cylinder')
plt.ylabel('Horse Power')
plt.title('Barplot using column cyl and hp')
plt.show()

# %%
# count plot

sns.countplot(y= df['cyl'], palette='Set1')
plt.show()

# %%
# heatmap
# +ve correaltion
#-ve correlation
df = pd.read_csv('/content/sample_data/mtcars.csv')
df  = df.drop(columns=['S.No', 'Unnamed: 1'])
sns.heatmap(df.corr())
# Out:
# <Axes: >
