# %% [markdown]
# <a href="https://colab.research.google.com/github/quantumhome/DataAnalysisCaseStudy/blob/master/Pandas_quiz_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('/content/sample_data/housing.csv')
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
# dataframe column info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# convert datatime column to date right format
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# checking the null in data set
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# highest bed room
filtered_df = df.loc[df['bedrooms'] == df['bedrooms'].max(), :]
filtered_df
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15870      6000     1.0           0     0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15870            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15870           1330        4700
#
# [1 rows x 21 columns]

# %%
# highest price
highest_price = df.loc[df['price'] == df['price'].max(), :]
highest_price
# Out:
#               id       date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020 2014-10-13  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
# hughest 5 prices by date
df.groupby('price')['bedrooms'].max()
# Out:
# price
# 75000      1
# 78000      2
# 80000      1
# 81000      2
# 82000      3
#           ..
# 5350000    5
# 5570000    5
# 6885000    6
# 7062500    5
# 7700000    6
# Name: bedrooms, Length: 4032, dtype: int64

# %%
# duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values('date', ascending=False)
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 16594  9106000005 2015-05-27  1310000         4       2.25         3750
# 13053  5101400871 2015-05-24   445500         2       1.75         1390
# 5637   7923600250 2015-05-15   450000         5       2.00         1870
# 928    8730000270 2015-05-14   359000         2       2.75         1370
# 6197   9178601660 2015-05-14  1695000         5       3.00         3320
# ...           ...        ...      ...       ...        ...          ...
# 20559  3438501320 2014-05-02   295000         2       2.50         1630
# 7323   2202500290 2014-05-02   435000         4       1.00         1450
# 12366   587550340 2014-05-02   604000         3       2.50         3240
# 9587   1024069009 2014-05-02   675000         5       2.50         2820
# 8326   2493200195 2014-05-02   615000         3       1.75         2360
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Shape
df.shape
# Out:
# (21613, 21)

# %%
List =[3,9,12,15]
a=(x**3 for x in List)
print(next(a))
# Out:
# 27

# %%
jobs="analyst"
jobs[5:6]
# Out:
# 's'

# %%
arr=np.array( [ [6,9,12] , [8,3,7] , [9,8,0] ] )
np.sum(arr,axis=0)
# Out:
# array([23, 20, 19])

# %%
N=np.array([ 99 , None , 49 , 'Nan', str ])
len(N)
# Out:
# 5

# %%
np.size(N)
# Out:
# 5

# %%
a = [[1, 0], [0, 1]]
b = [[4, 1], [2, 2]]
np.dot(a,b)
# Out:
# array([[4, 1],
#        [2, 2]])

# %%
df
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# filter =df['price'].max()
# df = df[df['price'] == filter]
# df

# %%
ds = df[df['grade'] == 10]
ds
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 66     3394100030 2014-09-09   975000         4       2.50         2720
# 75     3276920270 2014-11-05   832500         4       4.00         3430
# 79     1531000030 2015-03-23   720000         4       2.50         3450
# 91     5036300431 2015-03-11  1099880         5       2.75         3520
# 108    1853000400 2015-03-05   680000         4       2.50         3140
# ...           ...        ...      ...       ...        ...          ...
# 21568   524059330 2015-01-30  1700000         4       3.50         3830
# 21573  8562790760 2014-05-20   785000         4       3.50         3070
# 21576  9253900271 2015-01-07  3567000         5       4.50         4850
# 21593  8672200110 2015-03-17  1088000         5       3.75         4170
# 21597   191100405 2015-04-21  1575000         4       3.25         3410
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
ds = df[df['id'] == 9126100861]
ds
# Out:
#              id       date   price  bedrooms  bathrooms  sqft_living  \
# 400  9126100861 2015-03-06  557000         3        3.5         1710
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 400      2096     2.0           0     0  ...      8        1290
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 400            420      2008             0    98122  47.6055 -122.305
#
#      sqft_living15  sqft_lot15
# 400           1630        1543
#
# [1 rows x 21 columns]

# %%
# how many houses have 3 views
countviews = df[df['view'] == 3]
countviews
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 15     9297300055 2015-01-24   650000         4       3.00         2950
# 60     1516000055 2014-12-10   650000         3       2.25         2150
# 114    8961960160 2014-10-28   480000         4       2.50         3230
# 153    7855801670 2015-04-01  2250000         4       3.25         5180
# 216      46100204 2015-02-21  1505000         5       3.00         3300
# ...           ...        ...      ...       ...        ...          ...
# 21327  7394400080 2015-03-04   535000         4       3.25         2840
# 21344  8835770170 2014-08-22  1488000         5       6.00         6880
# 21505  9468200109 2014-06-17  1555000         3       3.50         4360
# 21539  8902000201 2015-02-19   338500         3       2.25         1333
# 21540   715010530 2015-01-13  1881583         5       3.50         4410
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# lowest price of the house
dl = df[df['price']==df['price'].min()]
dl
# Out:
#               id       date  price  bedrooms  bathrooms  sqft_living  \
# 1149  3421079032 2015-02-17  75000         1        0.0          670
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149     43377     1.0           0     0  ...      3         670
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149              0      1966             0    98022  47.2638 -121.906
#
#       sqft_living15  sqft_lot15
# 1149           1160       42882
#
# [1 rows x 21 columns]

# %%
# bigegst squar living
biggestsql = df[df['sqft_living']==df['sqft_living'].max()]
biggestsql
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 12777  1225069038 2014-05-05  2280000         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12777    307752     3.0           0     4  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12777           4850      217800
#
# [1 rows x 21 columns]

# %%
# dict = {'key1': 'value', 'key2': 'value2'}
# dsd= pd.DataFrame.from_dict(dict)
# dsd

# %%
# duplicate check
duplicateCheck = df[df.duplicated(['id','zipcode','grade'])]
duplicateCheck
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 94     6021501535 2014-12-23   700000         3       1.50         1580
# 314    4139480200 2014-12-09  1400000         4       3.25         4290
# 325    7520000520 2015-03-11   240500         2       1.00         1240
# 346    3969300030 2014-12-29   239900         4       1.00         1000
# 372    2231500030 2015-03-24   530000         4       2.25         2180
# ...           ...        ...      ...       ...        ...          ...
# 20181  7853400250 2015-02-19   645000         4       3.50         2910
# 20613  2724049222 2014-12-01   220000         2       2.50         1000
# 20670  8564860270 2015-03-30   502000         4       2.50         2680
# 20780  6300000226 2015-05-04   380000         4       1.00         1200
# 21581  7853420110 2015-05-04   625000         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
dups = df.duplicated(subset=['id','zipcode','grade'])
dups
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
ds = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])
ds.loc['r2':'r3']
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %%
housing = df
housing
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
h1 = housing[(housing["bedrooms"]==housing["bedrooms"].mean()) & (housing["view"]==3) & (housing["waterfront"]==1)]

# %%
sample_list = [['Carl', 22], ['Martha', 25], ['Calvin', 12], ['Stuart', 15] ]
pd.DataFrame(sample_list, columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
sample_dict = {'Cristiano': ['Ronaldo','Man U', 801], 'Lionel': ['Messi','PSG', 758],
               'Luis': ['Suarez','Atletico Madrid', 509], 'Robert': ['Lewandowski','Bayern Munich', 527],
               'Zlatan': ['Ibrahimovic','AC Milan',553] }

sample_dict
df1 = pd.DataFrame(sample_dict)
df1 = df1.transpose()
df1.reset_index(inplace = True)
df1.columns = ['First Name','Last Name', 'Club', 'Goals']
df1
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %%
sample_tuple = ([1, 'one', 3], [2, 'two', 3], [3, 'Three', 5], [4, 'Four', 4], [5, 'Five', 4])
dt = pd.DataFrame(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])
dt
# Out:
#    Number Number_text  txtlen
# 0       1         one       3
# 1       2         two       3
# 2       3       Three       5
# 3       4        Four       4
# 4       5        Five       4

# %%
# ascending and decending

ascending = housing.sort_values('price', ascending=True)

descending = housing.sort_values('price', ascending=False)
ascending
descending
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020 2014-10-13  7700000         6       8.00        12050
# 3914   9808700762 2014-06-11  7062500         5       4.50        10040
# 9254   9208900037 2014-09-19  6885000         6       7.75         9890
# 4411   2470100110 2014-08-04  5570000         5       5.75         9200
# 1448   8907500070 2015-04-13  5350000         5       5.00         8000
# ...           ...        ...      ...       ...        ...          ...
# 8274   3883800011 2014-11-05    82000         3       1.00          860
# 16198  3028200080 2015-03-24    81000         2       1.00          730
# 465    8658300340 2014-05-23    80000         1       0.75          430
# 15293    40000362 2014-05-06    78000         2       1.00          780
# 1149   3421079032 2015-02-17    75000         1       0.00          670
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
housing.corr()
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.005577 -0.016762  0.001286   0.005160    -0.012258
# date           0.005577  1.000000 -0.004357 -0.016800  -0.034410    -0.034559
# price         -0.016762 -0.004357  1.000000  0.308350   0.525138     0.702035
# bedrooms       0.001286 -0.016800  0.308350  1.000000   0.515884     0.576671
# bathrooms      0.005160 -0.034410  0.525138  0.515884   1.000000     0.754665
# sqft_living   -0.012258 -0.034559  0.702035  0.576671   0.754665     1.000000
# sqft_lot      -0.132109  0.006313  0.089661  0.031703   0.087740     0.172826
# floors         0.018525 -0.022491  0.256794  0.175429   0.500653     0.353949
# waterfront    -0.002721  0.001356  0.266369 -0.006582   0.063744     0.103818
# view           0.011592 -0.001800  0.397293  0.079532   0.187737     0.284611
# condition     -0.023783 -0.050769  0.036362  0.028472  -0.124982    -0.058753
# ...

# %%
housing['Floor Area'] = housing['sqft_living'] + housing['sqft_lot'] + housing['sqft_basement'] + housing['sqft_above']

housing
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# ...

# %%
housing['Floor Area'] = housing['sqft_living'] + housing['sqft_lot'] + housing['sqft_basement'] + housing['sqft_above']

housing
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# ...

# %%
A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], columns=['Name', 'Age'])
B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], columns=['Name', 'Age'])
inner = pd.merge(A, B, on='Age', how='inner')
outer = pd.merge(A, B, on='Age', how='outer')
left_outer = pd.merge(A, B, on='Age', how='left')
right_outer = pd.merge(A, B, on='Age', how='right')

# %%
# correlation between sqft_living and sqft_above
df['sqft_living'].corr(df['sqft_above'])
# Out:
# 0.876596598681318

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# Floor Area       0
# dtype: int64

# %%
df2 = pd.DataFrame([123.4567, 234.5678, 345.6789, 456.7890],
                  index=['foo','bar','baz','quux'],
                  columns=['cost'])
print(df2)
# Out:
#           cost
# foo   123.4567
# bar   234.5678
# baz   345.6789
# quux  456.7890

# %%
dict2 = {'key1' : [1,2,3], 'key2': [4,5,6]}
dsd = pd.DataFrame(dict2)
dsd
# Out:
#    key1  key2
# 0     1     4
# 1     2     5
# 2     3     6
