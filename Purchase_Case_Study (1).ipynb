# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/purchase_data.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# 1                               2             0.0                 1.0
# 2                               2             0.0                12.0
# 3                               2             0.0                12.0
# 4                              4+             0.0                 8.0
# ...                           ...             ...                 ...
# 263010                          3             0.0                 5.0
# 263011                          3             0.0                 1.0
# 263012                          3             0.0                 5.0
# 263013                          3             0.0                 5.0
# 263014                        NaN             NaN                 NaN
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN    8370.0
# 1                      6.0                14.0   15200.0
# 2                      NaN                 NaN    1422.0
# 3                     14.0                 NaN    1057.0
# 4                      NaN                 NaN    7969.0
# ...                    ...                 ...       ...
# 263010                18.0                 NaN    3722.0
# 263011                 8.0                17.0   19253.0
# 263012                 7.0                 NaN    3608.0
# 263013                 NaN                 NaN    3604.0
# 263014                 NaN                 NaN       NaN
#
# [263015 rows x 12 columns]

# %%
# EDA -->Explory Data Analysis
# 1.checking data discripency
# 2.null values
# 3.duplicates
# 4.outliers
# 5.label Encoding
# 6.infrences --> using infrential stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 24.1+ MB

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
df['Stay_In_Current_City_Years'].replace("4+","4",inplace=True)
# Out:
# <ipython-input-18-a49e527d5103>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stay_In_Current_City_Years'].replace("4+","4",inplace=True)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0', nan], dtype=object)

# %%
df[['Stay_In_Current_City_Years']]=df[['Stay_In_Current_City_Years']].fillna('0')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263015 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 24.1+ MB

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263015 non-null  int64
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 24.1+ MB

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array([2, 4, 3, 1, 0])

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         0
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             81514
# Product_Category_3            182433
# Purchase                           1
# dtype: int64

# %%
df[['Product_Category_2','Product_Category_3']]=df[['Product_Category_2','Product_Category_3']].fillna(0.0)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    1
# Gender                        1
# Age                           1
# Occupation                    1
# City_Category                 1
# Stay_In_Current_City_Years    0
# Marital_Status                1
# Product_Category_1            1
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      1
# dtype: int64

# %%
df[['Product_Category_2','Product_Category_3']]=df[['Product_Category_2','Product_Category_3']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263015 non-null  int64
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          263015 non-null  int64
#  10  Product_Category_3          263015 non-null  int64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 24.1+ MB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.drop_duplicates(inplace =True)

# %%
sns.boxplot(df['Purchase'])
# Out:
# <Axes: ylabel='Purchase'>

# %%
Q1=df['Purchase'].quantile(0.25)
Q3=df['Purchase'].quantile(0.75)
IQR=Q3-Q1

LB=Q1-1.5*IQR
UB=Q3+1.5*IQR

df=df[(df['Purchase']>=LB) & (df['Purchase']<=UB)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261725 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     261725 non-null  int64
#  1   Product_ID                  261725 non-null  object
#  2   Gender                      261725 non-null  object
#  3   Age                         261725 non-null  object
#  4   Occupation                  261725 non-null  float64
#  5   City_Category               261725 non-null  object
#  6   Stay_In_Current_City_Years  261725 non-null  int64
#  7   Marital_Status              261725 non-null  float64
#  8   Product_Category_1          261725 non-null  float64
#  9   Product_Category_2          261725 non-null  int64
#  10  Product_Category_3          261725 non-null  int64
#  11  Purchase                    261725 non-null  float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 26.0+ MB

# %%
# Label Encoding
cols=['Gender','Age','City_Category','Product_ID']
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in cols:
  df[col]=le.fit_transform(df[col])
# Out:
# <ipython-input-46-1e1606b97826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])
# <ipython-input-46-1e1606b97826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])
# <ipython-input-46-1e1606b97826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])
# <ipython-input-46-1e1606b97826>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261725 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     261725 non-null  int64
#  1   Product_ID                  261725 non-null  int64
#  2   Gender                      261725 non-null  int64
#  3   Age                         261725 non-null  int64
#  4   Occupation                  261725 non-null  float64
#  5   City_Category               261725 non-null  int64
#  6   Stay_In_Current_City_Years  261725 non-null  int64
#  7   Marital_Status              261725 non-null  float64
#  8   Product_Category_1          261725 non-null  float64
#  9   Product_Category_2          261725 non-null  int64
#  10  Product_Category_3          261725 non-null  int64
#  11  Purchase                    261725 non-null  float64
# dtypes: float64(4), int64(8)
# memory usage: 26.0 MB

# %%
df
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001         647       0    0        10.0              0
# 1       1000001        2304       0    0        10.0              0
# 2       1000001         814       0    0        10.0              0
# 3       1000001         790       0    0        10.0              0
# 4       1000002        2657       1    6        16.0              2
# ...         ...         ...     ...  ...         ...            ...
# 263009  1004473        2762       1    3         1.0              1
# 263010  1004473         403       1    3         1.0              1
# 263011  1004473        1015       1    3         1.0              1
# 263012  1004473        1717       1    3         1.0              1
# 263013  1004473        1058       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2             0.0                 3.0
# 1                                2             0.0                 1.0
# 2                                2             0.0                12.0
# 3                                2             0.0                12.0
# 4                                4             0.0                 8.0
# ...                            ...             ...                 ...
# 263009                           3             0.0                 8.0
# 263010                           3             0.0                 5.0
# 263011                           3             0.0                 1.0
# 263012                           3             0.0                 5.0
# 263013                           3             0.0                 5.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                        0                   0    8370.0
# 1                        6                  14   15200.0
# 2                        0                   0    1422.0
# 3                       14                   0    1057.0
# 4                        0                   0    7969.0
# ...                    ...                 ...       ...
# 263009                   0                   0    8061.0
# 263010                  18                   0    3722.0
# 263011                   8                  17   19253.0
# 263012                   7                   0    3608.0
# 263013                   0                   0    3604.0
#
# [261725 rows x 12 columns]

# %% [markdown]
# # **Statistical Analysis**

# %%
#getting infrences from dataset

#1.create a sample
#2.create hypothesis (HO(Null hypotheses) ad H1(Alternate hypo))
#3.Apply the appropriate test
#4.compare the p_value
  # a.if p_val>0.05  --> fail reject the null hypo (accecpt H0)
  # b.if p_val<=0.05  --> reject the null hypo (accecpt H1)

# %% [markdown]
# # a) It was observed that the average purchase made by the Men of the age 18-25 was 10000. Is it still the same?

# %% [markdown]
# **A one-sample t-test** is a statistical test used to determine whether the mean of a single sample is significantly different from a known or hypothesized population mean.
#
# It helps in testing hypotheses about the average value of a dataset.
#
# **Types of t-tests:**
#
# **One-sample t-test**: Compares the sample mean to a known value (population mean).
#
# **Independent two-sample t-test**: Compares the means of two independent groups.
#
# **Paired sample t-test**: Compares means from the same group at different times (e.g., before and after treatment).
#
# Key Concepts:
#
# Null Hypothesis (H₀): The sample mean is equal to the population mean.
#
# Alternative Hypothesis (H₁): The sample mean is different (greater or less) than the population mean.

# %%
# HO:-the avg purchase made by men (18-25) is 10000
# H1:-the avg purchase made by men (18-25) is not 10000

# %%
new_data=df[(df['Age']==1) & df['Gender']==1]

# %%
new_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 97      1000021        2024       1    1        16.0              1
# 98      1000022        3261       1    1        15.0              0
# 99      1000022        1954       1    1        15.0              0
# 100     1000022        1792       1    1        15.0              0
# 101     1000022        1020       1    1        15.0              0
# ...         ...         ...     ...  ...         ...            ...
# 262767  1004446        1311       1    1        18.0              1
# 262951  1004465        2880       1    1         4.0              0
# 262952  1004465        1296       1    1         4.0              0
# 262953  1004465        2733       1    1         4.0              0
# 262954  1004465        1424       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 97                               0             0.0                 3.0
# 98                               4             0.0                 1.0
# 99                               4             0.0                 5.0
# 100                              4             0.0                 3.0
# 101                              4             0.0                 8.0
# ...                            ...             ...                 ...
# 262767                           1             1.0                 1.0
# 262951                           1             1.0                 5.0
# 262952                           1             1.0                 2.0
# 262953                           1             1.0                 8.0
# 262954                           1             1.0                 8.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 97                      12                   0    3055.0
# 98                       8                  17   12099.0
# 99                       8                   0    8797.0
# 100                      4                   0   10681.0
# 101                     14                   0    7801.0
# ...                    ...                 ...       ...
# 262767                   2                   0   15431.0
# 262951                   0                   0    1763.0
# 262952                   3                   4    3240.0
# 262953                   0                   0    5832.0
# 262954                   0                   0    7788.0
#
# [36202 rows x 12 columns]

# %%
sample=new_data.sample(3600,random_state=5)

# %%
sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 207830  1002010         410       1    1         4.0              1
# 18139   1002859        1141       1    1         1.0              2
# 46341   1001138         973       1    1        12.0              2
# 203994  1001470         141       1    1         4.0              0
# 3206    1000524        2478       1    1         0.0              0
# ...         ...         ...     ...  ...         ...            ...
# 173759  1002894        2310       1    1         4.0              1
# 74445   1005482         795       1    1         7.0              0
# 37813   1005824         511       1    1        12.0              1
# 118037  1000202        2818       1    1         4.0              0
# 237335  1000636        2740       1    1        20.0              2
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 207830                           0             0.0                 5.0
# 18139                            0             0.0                 1.0
# 46341                            4             0.0                 1.0
# 203994                           1             1.0                 1.0
# 3206                             0             0.0                 8.0
# ...                            ...             ...                 ...
# 173759                           4             0.0                 1.0
# 74445                            1             0.0                 2.0
# 37813                            1             0.0                10.0
# 118037                           3             0.0                 8.0
# 237335                           4             0.0                 5.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 207830                  14                   0    5430.0
# 18139                    2                  15   15448.0
# 46341                    2                   0   19259.0
# 203994                   2                   5   15222.0
# 3206                    13                  14    2213.0
# ...                    ...                 ...       ...
# 173759                   5                  15    8096.0
# 74445                    4                   8   13029.0
# 37813                   15                   0   14128.0
# 118037                   0                   0    7885.0
# 237335                   8                  15    8764.0
#
# [3600 rows x 12 columns]

# %%
new_data['Purchase'].mean()
# Out:
# 9391.676371471189

# %%
from scipy.stats import ttest_1samp

# %%
a_mean=10000
t_stat,p_val=ttest_1samp(sample['Purchase'],a_mean)
print(p_val)
# Out:
# 1.7766468838738448e-09

# %%
val=1.7766468838738448e-10
print(f"{val: 0.25f}")
# Out:
#  0.0000000001776646883873845

# %%
# Conclusion --> the avg purchase made by men (18-25) is not 10000  (>10000)

# %% [markdown]
# # b) It was observed that the percentage of women that spend more than 10000 was 35%. Is it still the same?

# %%
# HO:-35% of wormen spend more than 10K
# H1:35% of wormen dose not spend more than 10K

# %%
data_new=df[df['Purchase']>10000]
data_new
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1       1000001        2304       0    0        10.0              0
# 5       1000003        1768       1    2        15.0              0
# 6       1000004        1684       1    4         7.0              1
# 7       1000004        3213       1    4         7.0              1
# 8       1000004        3481       1    4         7.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262997  1004472        2433       0    4        16.0              1
# 263001  1004472        1921       0    4        16.0              1
# 263002  1004472        1665       0    4        16.0              1
# 263003  1004472        3209       0    4        16.0              1
# 263011  1004473        1015       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                                2             0.0                 1.0
# 5                                3             0.0                 1.0
# 6                                2             1.0                 1.0
# 7                                2             1.0                 1.0
# 8                                2             1.0                 1.0
# ...                            ...             ...                 ...
# 262997                           0             1.0                 1.0
# 263001                           0             1.0                 1.0
# 263002                           0             1.0                15.0
# 263003                           0             1.0                 1.0
# 263011                           3             0.0                 1.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 1                        6                  14   15200.0
# 5                        2                   0   15227.0
# 6                        8                  17   19215.0
# 7                       15                   0   15854.0
# 8                       16                   0   15686.0
# ...                    ...                 ...       ...
# 262997                  11                  16   15175.0
# 263001                  11                  15   15430.0
# 263002                  16                   0   12567.0
# 263003                   2                  15   15387.0
# 263011                   8                  17   19253.0
#
# [89768 rows x 12 columns]

# %%
data_new['Gender'].value_counts()
# Out:
# Gender
# 1    71366
# 0    18402
# Name: count, dtype: int64

# %%
no_female=18402
total=len(data_new['Gender'])

prapotion=0.35

# %%
no_female,total,prapotion
# Out:
# (18402, 89768, 0.35)

# %%
no_female/total
# Out:
# 0.20499509847607164

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
z_val,p_val=proportions_ztest(count=no_female,nobs=total,value=prapotion)
print(z_val,p_val)
# Out:
# -107.61847057425669 0.0

# %%
# conclusion-->35% of wormen dose not spend more than 10K (==20.4)

# %%
# c)  Is the percentage of men who have spent more than 10000 the same for the ages 18-25 and 26-35?
# d) Is the average purchase made by men and women of the age 18-25 same
